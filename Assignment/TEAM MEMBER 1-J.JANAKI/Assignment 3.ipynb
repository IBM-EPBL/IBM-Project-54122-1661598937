# %% [markdown]
# 1.Download the dataset: Dataset : abalone.csv

# %% [markdown]
# 2.Load the dataset.

# %%
import pandas as pd

# %%
dataset = pd.read_csv("abalone.csv") # import may occures in different ways according ,where we store the data set
dataset.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings   Age
# 0         0.150     15  16.5
# 1         0.070      7   8.5
# 2         0.210      9  10.5
# 3         0.155     10  11.5
# 4         0.055      7   8.5

# %% [markdown]
# 3.Perform Below Visualizations. ● Univariate Analysis ● Bi - Variate Analysis ● Multi - Variate Analysis

# %%
import seaborn as sns

# %%
# univariate
sns.displot(dataset['Height'])

# %%
sns.displot(dataset['Rings'])

# %%
# bi variate
sns.relplot(x="Height",y='Age',data=dataset)

# %%
sns.relplot(x="Height",y='Age',hue="Diameter",data=dataset)

# %%
# multivariate
sns.pairplot(data=dataset,hue="Rings")

# %% [markdown]
# 4.Perform descriptive statistics on the dataset.

# %%
import pandas as pd
import numpy as np
ds = pd.read_csv("abalone.csv")  # import may occures in different ways according ,where we store the data set
ds.head(2)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
#
#    Shell weight  Rings   Age
# 0          0.15     15  16.5
# 1          0.07      7   8.5

# %%
ds.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# Age               False
# dtype: bool

# %%
ds.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings          Age
# count     4177.000000   4177.000000  4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684    11.433684
# std          0.109614      0.139203     3.224169     3.224169
# ...

# %% [markdown]
# 5.Handle the Missing values.

# %%
dataset.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings   Age
# 0         0.150     15  16.5
# 1         0.070      7   8.5
# 2         0.210      9  10.5
# 3         0.155     10  11.5
# 4         0.055      7   8.5

# %%
dataset.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# Age               0
# dtype: int64

# %% [markdown]
# dataset is not having any missing or null values.

# %% [markdown]
# 6.Find the outliers and replace the outliers

# %%
dataset.skew()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# Age               1.114102
# dtype: float64

# %%
sns.boxplot(dataset["Age"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
q2= dataset["Age"].describe()["25%"]
q3= dataset["Age"].describe()["75%"]

# %%
q2
# Out:
# 9.5

# %%
q3
# Out:
# 12.5

# %%
iqr=q3-q2
iqr
# Out:
# 3.0

# %%
l_b=q2-(1.5*iqr)
u_b=q3+(1.5*iqr)

# %%
l_b
# Out:
# 5.0

# %%
l_b=q2-(1.5*iqr)
u_b=q3+(1.5*iqr)

# %%
l_b
# Out:
# 5.0

# %%
u_b
# Out:
# 17.0

# %%
dataset[dataset["Age"]<l_b]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 306    I   0.165     0.120   0.030        0.0215          0.0070
# 520    M   0.210     0.150   0.050        0.0385          0.0155
# 526    M   0.155     0.110   0.040        0.0155          0.0065
# 719    I   0.150     0.100   0.025        0.0150          0.0045
# 720    I   0.160     0.110   0.025        0.0180          0.0065
# 894    I   0.240     0.175   0.065        0.0665          0.0310
# 1054   I   0.195     0.150   0.045        0.0375          0.0180
# 1429   I   0.140     0.105   0.035        0.0140          0.0055
# 2115   I   0.180     0.130   0.045        0.0275          0.0125
# 2371   M   0.180     0.125   0.050        0.0230          0.0085
# ...

# %%
dataset[dataset["Age"]>u_b].head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 6    F   0.530     0.415   0.150        0.7775          0.2370
# 7    F   0.545     0.425   0.125        0.7680          0.2940
# 9    F   0.550     0.440   0.150        0.8945          0.3145
# 32   M   0.665     0.525   0.165        1.3380          0.5515
# 33   F   0.680     0.550   0.175        1.7980          0.8150
#
#     Viscera weight  Shell weight  Rings   Age
# 6           0.1415         0.330     20  21.5
# 7           0.1495         0.260     16  17.5
# 9           0.1510         0.320     19  20.5
# 32          0.3575         0.350     18  19.5
# 33          0.3925         0.455     19  20.5

# %%
dataset.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# Age               float64
# dtype: object

# %%
outlier_list=list(dataset[dataset["Age"]>u_b]["Age"])
outlier_list
# Out:
# [21.5,
#  17.5,
#  20.5,
#  19.5,
#  20.5,
#  17.5,
#  21.5,
#  17.5,
#  22.5,
#  20.5,
#  19.5,
#  18.5,
#  17.5,
#  17.5,
#  19.5,
#  17.5,
#  21.5,
#  21.5,
#  22.5,
#  17.5,
#  23.5,
#  18.5,
#  20.5,
#  23.5,
#  17.5,
#  23.5,
#  19.5,
#  21.5,
#  18.5,
#  18.5,
#  20.5,
#  27.5,
#  22.5,
#  20.5,
#  24.5,
#  24.5,
#  19.5,
#  17.5,
#  17.5,
#  23.5,
#  17.5,
#  21.5,
#  19.5,
#  18.5,
#  17.5,
#  19.5,
#  21.5,
#  17.5,
#  20.5,
#  18.5,
#  17.5,
#  17.5,
#  20.5,
#  21.5,
#  17.5,
#  21.5,
#  21.5,
#  17.5,
#  19.5,
#  20.5,
#  22.5,
#  19.5,
#  19.5,
#  21.5,
#  19.5,
#  23.5,
#  20.5,
#  17.5,
#  19.5,
#  17.5,
#  17.5,
#  18.5,
#  18.5,
#  22.5,
#  18.5,
#  18.5,
#  22.5,
#  17.5,
#  30.5,
#  18.5,
#  20.5,
#  18.5,
#  20.5,
#  24.5,
#  18.5,
#  17.5,
#  21.5,
#  18.5,
#  17.5,
#  21.5,
#  18.5,
#  18.5,
#  20.5,
#  19.5,
#  20.5,
#  17.5,
#  18.5,
#  19.5,
#  19.5,
#  18.5,
#  22.5,
#  20.5,
#  18.5,
#  17.5,
#  19.5,
#  19.5,
#  20.5,
#  18.5,
#  20.5,
#  22.5,
#  24.5,
# ...

# %%
outlier_dict={}.fromkeys(outlier_list,u_b)
outlier_dict
# Out:
# {21.5: 17.0,
#  17.5: 17.0,
#  20.5: 17.0,
#  19.5: 17.0,
#  22.5: 17.0,
#  18.5: 17.0,
#  23.5: 17.0,
#  27.5: 17.0,
#  24.5: 17.0,
#  30.5: 17.0,
#  28.5: 17.0,
#  26.5: 17.0,
#  25.5: 17.0}

# %%
dataset["Age"]=dataset["Age"].replace(outlier_dict)
sns.boxplot(dataset["Age"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 7.Check for Categorical columns and perform encoding.

# %%
dataset.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# Age               float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
dataset['Lenght']=le.fit_transform(dataset['Height'])
dataset['Sex']=le.fit_transform(dataset['Sex'])

# %%
dataset.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings   Age  Lenght
# 0          0.1010         0.150     15  16.5      18
# 1          0.0485         0.070      7   8.5      17
# 2          0.1415         0.210      9  10.5      26
# 3          0.1140         0.155     10  11.5      24
# 4          0.0395         0.055      7   8.5      15

# %% [markdown]
# 8.Split the data into dependent and independent variables.

# %%
y=dataset['Diameter']
x=dataset.drop(columns=['Diameter','Age','Rings'],axis=1)

# %%
y
# Out:
# 0       0.365
# 1       0.265
# 2       0.420
# 3       0.365
# 4       0.255
#         ...
# 4172    0.450
# 4173    0.440
# 4174    0.475
# 4175    0.485
# 4176    0.555
# Name: Diameter, Length: 4177, dtype: float64

# %%
x
# Out:
#       Sex  Length  Height  Whole weight  Shucked weight  Viscera weight  \
# 0       2   0.455   0.095        0.5140          0.2245          0.1010
# 1       2   0.350   0.090        0.2255          0.0995          0.0485
# 2       0   0.530   0.135        0.6770          0.2565          0.1415
# 3       2   0.440   0.125        0.5160          0.2155          0.1140
# 4       1   0.330   0.080        0.2050          0.0895          0.0395
# ...   ...     ...     ...           ...             ...             ...
# 4172    0   0.565   0.165        0.8870          0.3700          0.2390
# 4173    2   0.590   0.135        0.9660          0.4390          0.2145
# 4174    2   0.600   0.205        1.1760          0.5255          0.2875
# 4175    0   0.625   0.150        1.0945          0.5310          0.2610
# 4176    2   0.710   0.195        1.9485          0.9455          0.3765
#
#       Shell weight  Lenght
# 0           0.1500      18
# 1           0.0700      17
# ...

# %% [markdown]
# 9.Scale the independent variables

# %%
col_names=x.columns
from sklearn.preprocessing import scale

# %%
x=scale(x) # convert to array
x
# Out:
# array([[ 1.15198011, -0.57455813, -1.06442415, ..., -0.72621157,
#         -0.63821689, -1.14805951],
#        [ 1.15198011, -1.44898585, -1.18397831, ..., -1.20522124,
#         -1.21298732, -1.27780638],
#        [-1.28068972,  0.05003309, -0.10799087, ..., -0.35668983,
#         -0.20713907, -0.11008449],
#        ...,
#        [ 1.15198011,  0.6329849 ,  1.56576738, ...,  0.97541324,
#          0.49695471,  1.70637178],
#        [-1.28068972,  0.84118198,  0.25067161, ...,  0.73362741,
#          0.41073914,  0.27915614],
#        [ 1.15198011,  1.54905203,  1.32665906, ...,  1.78744868,
#          1.84048058,  1.44687803]])

# %%
x=pd.DataFrame(x,columns=col_names) #Convert the array back to the DataFrame
x
# Out:
#            Sex    Length    Height  Whole weight  Shucked weight  \
# 0     1.151980 -0.574558 -1.064424     -0.641898       -0.607685
# 1     1.151980 -1.448986 -1.183978     -1.230277       -1.170910
# 2    -1.280690  0.050033 -0.107991     -0.309469       -0.463500
# 3     1.151980 -0.699476 -0.347099     -0.637819       -0.648238
# 4    -0.064355 -1.615544 -1.423087     -1.272086       -1.215968
# ...        ...       ...       ...           ...             ...
# 4172 -1.280690  0.341509  0.609334      0.118813        0.047908
# 4173  1.151980  0.549706 -0.107991      0.279929        0.358808
# 4174  1.151980  0.632985  1.565767      0.708212        0.748559
# 4175 -1.280690  0.841182  0.250672      0.541998        0.773341
# 4176  1.151980  1.549052  1.326659      2.283681        2.640993
#
#       Viscera weight  Shell weight    Lenght
# 0          -0.726212     -0.638217 -1.148060
# 1          -1.205221     -1.212987 -1.277806
# 2          -0.356690     -0.207139 -0.110084
# ...

# %% [markdown]
# 10.Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (3341, 8)

# %%
x_test.shape
# Out:
# (836, 8)

# %%
y_train.shape
# Out:
# (3341,)

# %%
y_test.shape
# Out:
# (836,)
